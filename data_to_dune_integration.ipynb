# %%
import pandas as pd
import json

def load_secrets(secrets_file_path):
    with open(secrets_file_path, 'r') as file:
        secrets = json.load(file)
    return secrets


# Load the JSON file into a DataFrame
csv_file_path1 = 'data/song_metadata_enhanced.csv'

csv_file_path2 = 'data/song_metadata.csv'

# Path to the secrets file
secrets_path = 'secrets.json'  # Update this path as needed

# Load secrets
secrets = load_secrets(secrets_path)
# print(secrets['dune_api_key'])  # Example usage of a loaded secret

# Loading the kiosk data into a DataFrame
song_metadata_df = pd.read_csv(csv_file_path1)

# Loading the kiosk data into a DataFrame
song_metadata_enhanced_df = pd.read_csv(csv_file_path2)

display(song_metadata_df)
display(song_metadata_enhanced_df)
# Out:
#      Catalog            Dabow                          Olé  \
# 0    Catalog            XEDRA                INFOMASOCHIST
# 1    Catalog            JediP                      *sunset
# 2        NaN     Jadyn Violet    We were younger yesterday
# 3    Catalog        p3t3rango        IOI ft. Alan Zavodsky
# 4    Catalog       HOUNDTRACK                        Havoc
# 5    Catalog        Pozibelle                   Walk On By
# 6    Catalog         Subp Yao                        Depth
# 7        NaN   Jamee Cornelia  Neon Nights ft Jadyn Violet
# 8    Catalog  cumulus frisbee                    Hyperplex
# 9    Catalog         Dutchyyy           Yawn of the Gemini
# 10   Catalog              dot                   Super Moon
# 11   Catalog        IAMNOBODI        Play Your Cards Right
# 12   Catalog          maddeof                     One Time
# 13   Catalog       malfnktion                     violet22
# 14   Catalog            MELVV                      Want It
# ...
